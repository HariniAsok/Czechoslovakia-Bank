# %% [markdown]
# <a href="https://colab.research.google.com/github/HariniAsok/Czechoslovakia-Bank/blob/main/Czechoslovakia_Bank_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
account = pd.read_csv('/content/account.csv')

account
# Out:
#      account_id  district_id         frequency        date
# 0           576           55  POPLATEK MESICNE  1993-01-01
# 1          3818           74  POPLATEK MESICNE  1993-01-01
# 2           704           55  POPLATEK MESICNE  1993-01-01
# 3          2378           16  POPLATEK MESICNE  1993-01-01
# 4          2632           24  POPLATEK MESICNE  1993-01-02
# ..          ...          ...               ...         ...
# 995        9656           61  POPLATEK MESICNE  1993-11-14
# 996        1941           60  POPLATEK MESICNE  1993-11-15
# 997        3617           22  POPLATEK MESICNE  1993-11-15
# 998        3370           49  POPLATEK MESICNE  1993-11-15
# 999        1664           56  POPLATEK MESICNE  1993-11-15
#
# [1000 rows x 4 columns]

# %%
card = pd.read_csv('/content/card.csv')

card
# Out:
#      card_id  disp_id     type               issued
# 0       1005     9285  classic  1993-11-07 12:00:00
# 1        104      588  classic  1994-01-19 12:00:00
# 2        747     4915  classic  1994-02-05 12:00:00
# 3         70      439  classic  1994-02-08 12:00:00
# 4        577     3687  classic  1994-02-15 12:00:00
# ..       ...      ...      ...                  ...
# 887      125      694     gold  1998-12-26 12:00:00
# 888      674     4360  classic  1998-12-28 12:00:00
# 889      322     2063  classic  1998-12-28 12:00:00
# 890      685     4467  classic  1998-12-29 12:00:00
# 891      635     4083  classic  1998-12-29 12:00:00
#
# [892 rows x 4 columns]

# %%
client = pd.read_csv('/content/client.csv')

client
# Out:
#       Unnamed: 0  client_id  birth_number  district_id  gender  age  \
# 0              1          1        701213           18  FEMALE   29
# 1              2          2        450204            1    MALE   54
# 2              3          3        401009            1  FEMALE   59
# 3              4          4        561201            5    MALE   43
# 4              5          5        600703            5  FEMALE   39
# ...          ...        ...           ...          ...     ...  ...
# 5364        5365      13955        451030            1  FEMALE   54
# 5365        5366      13956        430406            1    MALE   56
# 5366        5367      13968        680413           61    MALE   31
# 5367        5368      13971        621019           67  FEMALE   37
# 5368        5369      13998        530812           74  FEMALE   46
#
#        age_levels
# 0           ADULT
# 1     MIDDLE AGED
# 2     MIDDLE AGED
# 3     MIDDLE AGED
# 4     MIDDLE AGED
# ...           ...
# ...

# %%
disp = pd.read_csv('/content/disp.csv')

disp
# Out:
#      disp_id  client_id  account_id       type
# 0          1          1           1      OWNER
# 1          2          2           2      OWNER
# 2          3          3           2  DISPONENT
# 3          4          4           3      OWNER
# 4          5          5           3  DISPONENT
# ..       ...        ...         ...        ...
# 995     1049       1049         871      OWNER
# 996     1050       1050         872      OWNER
# 997     1051       1051         873      OWNER
# 998     1052       1052         874      OWNER
# 999     1053       1053         874  DISPONENT
#
# [1000 rows x 4 columns]

# %%
district = pd.read_csv('/content/district.csv')

district
# Out:
#     district_id               A2           Region       A4  A5  A6  A7  A8  \
# 0             1      Hl.m. Praha           Prague  1204953   0   0   0   1
# 1             2          Benesov  central Bohemia    88884  80  26   6   2
# 2             3           Beroun  central Bohemia    75232  55  26   4   1
# 3             4           Kladno  central Bohemia   149893  63  29   6   2
# 4             5            Kolin  central Bohemia    95616  65  30   4   1
# ..          ...              ...              ...      ...  ..  ..  ..  ..
# 71           73            Opava    north Moravia   182027  17  49  12   2
# 72           74  Ostrava - mesto    north Moravia   323870   0   0   0   1
# 73           75           Prerov    north Moravia   138032  67  30   4   2
# 74           76          Sumperk    north Moravia   127369  31  32  13   2
# 75           77           Vsetin    north Moravia   148545   8  35  12   3
#
#     A9    A10 Average Salary   A12   A13  A14    A15    A16
# ...

# %%
loan = pd.read_csv('/content/loan.csv')

loan
# Out:
#      loan_id  account_id                 date  amount  duration  payments  \
# 0       5314        1787  1993-07-05 00:00:00   96396        12      8033
# 1       5316        1801  1993-07-11 00:00:00  165960        36      4610
# 2       6863        9188  1993-07-28 00:00:00  127080        60      2118
# 3       5325        1843  1993-08-03 00:00:00  105804        36      2939
# 4       7240       11013  1993-09-06 00:00:00  274740        60      4579
# ..       ...         ...                  ...     ...       ...       ...
# 495     5973        4784  1997-11-24 00:00:00  219456        48      4572
# 496     6075        5267  1997-11-26 00:00:00  129312        24      5388
# 497     5281        1580  1997-11-27 00:00:00  194256        24      8094
# 498     5103         666  1997-11-28 00:00:00   12540        12      1045
# 499     6468        7176  1997-11-30 00:00:00  203940        60      3399
#
#     status
# 0        B
# 1        A
# 2        A
# 3        A
# 4        A
# ...

# %%
orde = pd.read_csv('/content/orde.csv')

orde
# Out:
#      order_id  account_id bank_to  account_to  amount  k_symbol
# 0       29401           1      YZ    87144583  2452.0      SIPO
# 1       29402           2      ST    89597016  3372.7      UVER
# 2       29403           2      QR    13943797  7266.0      SIPO
# 3       29404           3      WX    83084338  1135.0      SIPO
# 4       29406           3      AB    59972357  3539.0  POJISTNE
# ..        ...         ...     ...         ...     ...       ...
# 578     30206         536      AB    84382724  1742.0      SIPO
# 579     30207         536      AB    56864386   827.0      SIPO
# 580     30208         537      ST    79339456  1848.0      SIPO
# 581     30209         538      OP     5225766  2692.0      SIPO
# 582     30210         541      IJ    97866481  3030.0      SIPO
#
# [583 rows x 6 columns]

# %%
trans = pd.read_csv('/content/transac.csv')

trans
# Out:
#     trans_id  account_id              date    type       operation  amount  \
# 0     637742        2177  05-01-1993 00:00  PRIJEM   PREVOD Z UCTU    5123
# 1     579374        1972  07-01-1993 00:00  PRIJEM   PREVOD Z UCTU    5298
# 2    1049882        3592  10-01-1993 00:00  PRIJEM   PREVOD Z UCTU    6007
# 3     171813         576  11-01-1993 00:00  PRIJEM   PREVOD Z UCTU    6207
# 4     689828        2357  12-01-1993 00:00  PRIJEM   PREVOD Z UCTU    6434
# 5     477639        1628  12-01-1993 00:00  PRIJEM   PREVOD Z UCTU    4276
# 6     439036        1493  13-01-1993 00:00  PRIJEM   PREVOD Z UCTU    5009
# 7     480215        1637  13-01-1993 00:00  PRIJEM   PREVOD Z UCTU    5718
# 8    2908689        9635  14-01-1993 00:00  PRIJEM   PREVOD Z UCTU    4470
# 9     637743        2177  05-02-1993 00:00  PRIJEM   PREVOD Z UCTU    5123
# 10    498391        1699  05-02-1993 00:00  PRIJEM   PREVOD Z UCTU    5224
# ...

# %%
trans.isnull().sum()
# Out:
# trans_id      0
# account_id    0
# date          0
# type          0
# operation     0
# amount        0
# balance       0
# k_symbol      0
# bank          0
# account       0
# dtype: int64

# %%
print("\nInfo for account Card Data:")
print(account.info())

print("\nInfo for Credit Card Data:")
print(card.info())

print("\nInfo for Client Data:")
print(client.info())

print("\nInfo for Disposition Data:")
print(disp.info())

print("\nInfo for District Data:")
print(district.info())

print(loan.info())

print("\nInfo for Order Data:")
print(orde.info())

print("\nInfo for Transaction Data:")
print(trans.info())
# Out:
# Info for account Card Data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   account_id   1000 non-null   int64
#  1   district_id  1000 non-null   int64
#  2   frequency    1000 non-null   object
#  3   date         1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 31.4+ KB
# None
#
# Info for Credit Card Data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   card_id  892 non-null    int64
#  1   disp_id  892 non-null    int64
#  2   type     892 non-null    object
#  3   issued   892 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 28.0+ KB
# None
#
# Info for Client Data:
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# **Demographics**

# %%
demographics = client.groupby('district_id').agg({
    'age': 'mean',  # Calculate mean of 'age'
    'client_id': 'count',  # Count the number of clients
    'gender': lambda x: x.value_counts().idxmax()  # Find the most common gender
}).reset_index()

# Rename columns for easier access
demographics.columns = ['district_id', 'avg_age', 'client_count', 'most_common_gender']

# Print the resulting DataFrame
print(demographics)
# Out:
#     district_id    avg_age  client_count most_common_gender
# 0             1  45.855204           663               MALE
# 1             2  40.369565            46             FEMALE
# 2             3  46.746032            63               MALE
# 3             4  45.780000            50               MALE
# 4             5  44.366197            71             FEMALE
# ..          ...        ...           ...                ...
# 72           73  45.100000            60               MALE
# 73           74  45.005556           180               MALE
# 74           75  49.071429            56               MALE
# 75           76  48.786885            61               MALE
# 76           77  45.280000            50               MALE
#
# [77 rows x 4 columns]

# %%
# Plot average age across districts
plt.figure(figsize=(12, 6))
sns.barplot(data=demographics, x='district_id', y='avg_age')
plt.title('Average Age by District')
plt.xlabel('District ID')
plt.ylabel('Average Age')
plt.show()


# Plot client count across districts
plt.figure(figsize=(12, 6))
sns.barplot(data=demographics, x='district_id', y='client_count')
plt.title('Client Count by District')
plt.xlabel('District ID')
# Out:
# Text(0.5, 0, 'District ID')

# %% [markdown]
# **Porformance of Bank by year & month-wise.**

# %%
# Join account and loan (data) on account_id
merge = pd.merge(account, loan, on='account_id', how='inner')

merge
# Out:
#      account_id  district_id         frequency     date_x  loan_id     date_y  \
# 0          5270           44  POPLATEK MESICNE 1993-01-13     6077 1993-11-22
# 1         11265           15  POPLATEK MESICNE 1993-01-14     7284 1993-09-15
# 2         10364           55  POPLATEK MESICNE 1993-01-17     7121 1993-11-10
# 3          3834           54  POPLATEK MESICNE 1993-01-19     5754 1994-09-28
# 4          9307           68  POPLATEK MESICNE 1993-01-24     6895 1994-09-19
# ..          ...          ...               ...        ...      ...        ...
# 126        4079           52  POPLATEK MESICNE 1993-11-03     5804 1995-04-05
# 127        3354           63  POPLATEK MESICNE 1993-11-05     5657 1994-07-05
# 128        7965           55  POPLATEK MESICNE 1993-11-08     6624 1994-09-30
# 129        8625           64  POPLATEK MESICNE 1993-11-10     6745 1995-04-10
# 130        9656           61  POPLATEK MESICNE 1993-11-14     6965 1995-06-13
#
# ...

# %%
merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   account_id   131 non-null    int64
#  1   district_id  131 non-null    int64
#  2   frequency    131 non-null    object
#  3   date_x       131 non-null    datetime64[ns]
#  4   loan_id      131 non-null    int64
#  5   date_y       131 non-null    datetime64[ns]
#  6   amount       131 non-null    int64
#  7   duration     131 non-null    int64
#  8   payments     131 non-null    int64
#  9   status       131 non-null    object
#  10  year         131 non-null    int32
#  11  month        131 non-null    int32
# dtypes: datetime64[ns](2), int32(2), int64(6), object(2)
# memory usage: 11.4+ KB

# %%
account.dtypes
# Out:
# account_id              int64
# district_id             int64
# frequency              object
# date           datetime64[ns]
# dtype: object

# %%
# Convert the 'date' column to datetime format if needed
account['date'] = pd.to_datetime(account['date'])

# %%
loan.dtypes
# Out:
# loan_id                int64
# account_id             int64
# date          datetime64[ns]
# amount                 int64
# duration               int64
# payments               int64
# status                object
# year                   int32
# month                  int32
# dtype: object

# %%
# Convert the 'DATE' column to datetime format if needed
loan['date'] = pd.to_datetime(loan['date'])

# %%
loan['date'].dt.month
# Out:
# 0       7
# 1       7
# 2       7
# 3       8
# 4       9
#        ..
# 495    11
# 496    11
# 497    11
# 498    11
# 499    11
# Name: date, Length: 500, dtype: int32

# %%
# Extract year and month from the 'date' column
loan['year'] = loan['date'].dt.year
loan['month'] = loan['date'].dt.month

# %%
loan_amounts = loan.groupby(['year', 'month'])['amount'].sum()

loan_amounts
# Out:
# year  month
# 1993  7         389436
#       8         105804
#       9         590112
#       10        154416
#       11        218556
#       12       1160952
# 1994  1         568836
#       2         775704
#       3         692580
#       4         381624
#       5        1440252
#       6        2072496
#       7        1766076
#       8        1366956
#       9        1101096
#       10        718308
#       11        873204
#       12       1622772
# 1995  1        1588032
#       2        1468788
#       3        1176732
#       4        1154796
#       5         729720
#       6        1113300
#       7         909264
#       8         272664
#       9         620268
#       10       1625940
#       11        983784
#       12       1701084
# 1996  1         699240
#       2        1290024
#       3         918696
#       4        1419384
#       5        1516044
#       6        1167792
#       7        1491996
#       8        2472924
#       9        1231956
# ...

# %%
 # Reset index to convert the groupby result to a DataFrame
loan_amounts = loan_amounts.reset_index()

# %% [markdown]
# **Year Wise**

# %%
# Extract year from the 'date' column
loan['year'] = loan['date'].dt.year

# Group the data by year and calculate total loan amount for each year
yearly_loan_amounts = loan.groupby('year')['amount'].sum()

# Reset index to convert the groupby result to a DataFrame
yearly_loan_amounts = yearly_loan_amounts.reset_index()

# Plot the loan amounts over time
plt.figure(figsize=(10, 6))
plt.bar(yearly_loan_amounts['year'], yearly_loan_amounts['amount'])
plt.xlabel('Year')
plt.ylabel('Total Loan Amount')
plt.title('Total Loan Amount Over year')
# Out:
# Text(0.5, 1.0, 'Total Loan Amount Over year')

# %% [markdown]
# **Month Wise**

# %%
# Extract month from the 'date' column
loan['month'] = loan['date'].dt.month

# Group the data by month and calculate total loan amount for each month
monthly_loan_amounts = loan.groupby('month')['amount'].sum()

# Plot the loan amounts month-wise
plt.figure(figsize=(10, 6))
plt.bar(monthly_loan_amounts.index, monthly_loan_amounts.values)
plt.xlabel('Month')
plt.ylabel('Total Loan Amount')
plt.title('Total Loan Amount Month-wise')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.tight_layout()
plt.show()

# %% [markdown]
# **Common types of accounts and its different usage and profitability**

# %%
# Count occurrences of each account type
account_type_counts = account['frequency'].value_counts()

# Display the most common account types
print("Most common types of accounts:")
print(account_type_counts)
# Out:
# Most common types of accounts:
# frequency
# POPLATEK MESICNE      925
# POPLATEK TYDNE         57
# POPLATEK PO OBRATU     18
# Name: count, dtype: int64

# %%
# Calculate usage metrics
total_transactions = trans['amount'].sum()
average_transaction_amount = trans['amount'].mean()

print('total_transactions:',  total_transactions)
print('average_transaction_amount:', average_transaction_amount)
# Out:
# total_transactions: 194098
# average_transaction_amount: 5545.657142857143

# %%
# Profitablity
total_loan_amount = loan['amount'].sum()
average_loan_amount = loan['amount'].mean()


print('total_loan_amount:', total_loan_amount)
print('average_loan_amount:', average_loan_amount)
# Out:
# total_loan_amount: 74620872
# average_loan_amount: 149241.744

# %% [markdown]
# **Type of cards used frequently**

# %%
card_types = card['type'].unique()

card_types
# Out:
# array(['classic', 'junior', 'gold'], dtype=object)

# %%
card_usage_counts = card['type'].value_counts()

card_usage_counts
# Out:
# type
# classic    659
# junior     145
# gold        88
# Name: count, dtype: int64

# %%
# Calculate Profitability

card_transactions = trans[trans['operation'] == 'VYBER KARTOU']
profitability = card_transactions['amount'].sum()

card_transactions

print('Most frequently used card:', 'classic')

print('Overall profitability:' ,profitability)
# Out:
# Most frequently used card: classic
# Overall profitability: 516100.0

# %% [markdown]
# **Major expenses of the bank**

# %%
credits = trans[trans['type'] == 'PRIJEM']
debits = trans[trans['type'] == 'VYDAJ']

# %%
# Convert the date column to datetime format
trans['date'] = pd.to_datetime(trans['date'], format="%d-%m-%Y %H:%M")

# Add year and month columns for aggregation
trans['year'] = trans['date'].dt.year
trans['month'] = trans['date'].dt.month

# %%
# Aggregate data to find total debits and credits per year and month
monthly_aggregation = trans.groupby(['year', 'month', 'type']).agg({'amount': 'sum'}).reset_index()

monthly_aggregation
# Out:
#    year  month    type  amount
# 0  1993      1  PRIJEM   48542
# 1  1993      2  PRIJEM  135944
# 2  1993      2   VYDAJ    9612

# %%
# Sum up loan payments
loan_expenses = loan.groupby('status')['amount'].sum().reset_index()


loan_expenses
# Out:
#   status    amount
# 0      A  18354984
# 1      B   4362348
# 2      C  42899940
# 3      D   9003600

# %%
# Sum up orders (assuming they represent debits)
order_expenses = orde.groupby('k_symbol')['amount'].sum().reset_index()
order_expenses.columns = ['k_symbol', 'total_amount']

order_expenses
# Out:
#    k_symbol  total_amount
# 0   LEASING      110603.7
# 1  POJISTNE       60662.0
# 2      SIPO     1667804.0
# 3      UVER      186024.7

# %%
# Combine all expenses into a single DataFrame
total_expenses = pd.concat([loan_expenses, order_expenses])
#total_expenses = total_expenses.groupby(total_expenses.columns[0])['total_amount'].sum().reset_index()
print(total_expenses)
# Out:
#   status      amount  k_symbol  total_amount
# 0      A  18354984.0       NaN           NaN
# 1      B   4362348.0       NaN           NaN
# 2      C  42899940.0       NaN           NaN
# 3      D   9003600.0       NaN           NaN
# 0    NaN         NaN   LEASING      110603.7
# 1    NaN         NaN  POJISTNE       60662.0
# 2    NaN         NaN      SIPO     1667804.0
# 3    NaN         NaN      UVER      186024.7

# %%
# Plot the total expenses by category
plt.figure(figsize=(12, 6))
sns.barplot(data=total_expenses, x='amount', y='status')
plt.title('Total Expenses by Category')
plt.xlabel('Total Amount')
plt.ylabel('Expense Category')
plt.show()

# %% [markdown]
# **Bank portfolio**

# %%
loan_account = loan.merge(account, on='account_id')

loan_account_disp = loan_account.merge(disp, on='account_id')

loan_client = loan_account_disp.merge(client, on='client_id')



loan_client

# Group by status to analyze loan performance
loan_portfolio = loan_client.groupby('status').agg(
    total_loan_amount=('amount', 'sum'),
    number_of_loans=('loan_id', 'count'),
    average_loan_amount=('amount', 'mean')
)


loan_portfolio
# Out:
#         total_loan_amount  number_of_loans  average_loan_amount
# status
# A                  234840                4              58710.0
# B                  208128                1             208128.0
# C                   87216                1              87216.0

# %%
loan_summary = loan[['amount', 'duration', 'payments', 'status']].describe()
print(loan_summary)
# Out:
#               amount    duration    payments
# count     500.000000  500.000000   500.00000
# mean   149241.744000   36.192000  4206.82000
# std    111609.595249   17.037361  2242.29255
# min      4980.000000   12.000000   312.00000
# 25%     67887.000000   24.000000  2345.50000
# 50%    110124.000000   36.000000  3934.00000
# 75%    207480.000000   48.000000  5996.00000
# max    590820.000000   60.000000  9910.00000

# %%
loan_status_distribution = loan['status'].value_counts()
print(loan_status_distribution)
# Out:
# status
# C    234
# A    197
# D     38
# B     31
# Name: count, dtype: int64

# %% [markdown]
# Vary across different purpose and client segments

# %%
# Distribution by gender
gender_distribution = client['gender'].value_counts()
print(gender_distribution)
# Out:
# gender
# MALE      2724
# FEMALE    2645
# Name: count, dtype: int64

# %%
# Distribution by age
age_distribution = client['age'].value_counts().sort_index()
print("Age distribution of loan clients:\n", age_distribution)
# Out:
# Age distribution of loan clients:
#  age
# 12    1
# 13    1
# 14    3
# 15    1
# 16    3
#      ..
# 84    4
# 85    4
# 86    3
# 87    1
# 88    2
# Name: count, Length: 77, dtype: int64

# %%
# Distribution by age levels
age_distribution = client['age_levels'].value_counts().sort_index()
print("Age distribution of loan clients:\n", age_distribution)
# Out:
# Age distribution of loan clients:
#  age_levels
# ADULT          1045
# MIDDLE AGED    2730
# SENIOR          875
# YOUTH           719
# Name: count, dtype: int64

# %%
# Aggregate loans by status to understand different purposes
loan_purpose_summary = loan.groupby('status').agg({'amount': 'sum', 'loan_id': 'count'}).reset_index()
loan_purpose_summary.columns = ['purpose', 'total_amount', 'number_of_loans']
print(loan_purpose_summary)
# Out:
#   purpose  total_amount  number_of_loans
# 0       A      18354984              197
# 1       B       4362348               31
# 2       C      42899940              234
# 3       D       9003600               38

# %% [markdown]
# **How can the bank improve its customer service and satisfaction levels**

# %% [markdown]
# By gathering comprehensive customer data including demographics, transaction history, and preferences.
#
# Utilizing the advanced analytics to segment customers into distinct groups based on their financial behaviors and needs.
#
#
# Developing the targeted marketing campaigns and promotions tailored to specific customer segments.

# %% [markdown]
# **Can the bank introduce new financial products or services to attract more customers and increase profitability**

# %%
# Analyze loan status
loan_status_counts = loan['status'].value_counts()
loan_default_rate = loan_status_counts['B'] / loan_status_counts.sum()

print("Loan Status Counts:")
print(loan_status_counts)

print("\nLoan Default Rate:")
print(loan_default_rate)
# Out:
# Loan Status Counts:
# status
# C    234
# A    197
# D     38
# B     31
# Name: count, dtype: int64
#
# Loan Default Rate:
# 0.062

# %%
# Merge client and district data
client_district_df = pd.merge(client, district, on='district_id')

# Segment clients based on demographic information
client_segments = client_district_df.groupby(['Region', 'Average Salary']).size().reset_index(name='count')

print("Client Segments:")
print(client_segments)
# Out:
# Client Segments:
#              Region Average Salary  count
# 0            Prague       ? 12,541    663
# 1   central Bohemia       ? 10,124     54
# 2   central Bohemia       ? 11,277     69
# 3   central Bohemia        ? 8,507     46
# 4   central Bohemia        ? 8,546     53
# ..              ...            ...    ...
# 71     west Bohemia        ? 8,624     53
# 72     west Bohemia        ? 8,843     54
# 73     west Bohemia        ? 8,930     59
# 74     west Bohemia        ? 8,991     43
# 75     west Bohemia        ? 9,650     48
#
# [76 rows x 3 columns]

# %%
# Trasaction Analysis

# Analyze transaction purposes
trans_purposes = trans['k_symbol'].value_counts()

print("Transaction Purposes:")
print(trans_purposes)
# Out:
# Transaction Purposes:
# k_symbol
# DUCHOD    34
# SIPO       1
# Name: count, dtype: int64

# %% [markdown]
# By analyzing loan performance, segmenting clients, and understanding transaction patterns,we can identify potential opportunities for the bank to introduce new financial products or services.
# This analysis will help the bank attract more customers and increase profitability.
